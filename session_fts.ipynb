# %%
import pandas as pd
import numpy as np

from utils import *

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
train = load_data('train', nrows=None)

# %%
dups = train[train.duplicated(subset=['user_id', 'session_id', 'timestamp'], keep=False)]

# %%
dups['device'].value_counts()
# Out:
# mobile     5881579
# desktop    5657871
# tablet     1002090
# Name: device, dtype: int64

# %%
train.device.value_counts()
# Out:
# mobile     7643538
# desktop    7003938
# tablet     1285516
# Name: device, dtype: int64

# %%
dups.head(30)
# Out:
#          user_id     session_id   timestamp  step             action_type  \
# 1   00RL8Z82B2Z1  aff3928535f48  1541037522     2  interaction item image
# 2   00RL8Z82B2Z1  aff3928535f48  1541037522     3  interaction item image
# 3   00RL8Z82B2Z1  aff3928535f48  1541037532     4  interaction item image
# 4   00RL8Z82B2Z1  aff3928535f48  1541037532     5  interaction item image
# 5   00RL8Z82B2Z1  aff3928535f48  1541037532     6  interaction item image
# 6   00RL8Z82B2Z1  aff3928535f48  1541037532     7  interaction item image
# 7   00RL8Z82B2Z1  aff3928535f48  1541037532     8  interaction item image
# 8   00RL8Z82B2Z1  aff3928535f48  1541037542     9  interaction item image
# 9   00RL8Z82B2Z1  aff3928535f48  1541037542    10  interaction item image
# 10  00RL8Z82B2Z1  aff3928535f48  1541037542    11  interaction item image
# 11  00RL8Z82B2Z1  aff3928535f48  1541037542    12  interaction item image
# 12  00RL8Z82B2Z1  aff3928535f48  1541037542    13  interaction item image
# 17  02HGRBA06ODU  fa3a53156ae5c  1541030843     2  interaction item image
# 18  02HGRBA06ODU  fa3a53156ae5c  1541030843     3  interaction item image
# 21  02HGRBA06ODU  fa3a53156ae5c  1541030877     6  interaction item image
# 22  02HGRBA06ODU  fa3a53156ae5c  1541030877     7  interaction item image
# 23  02HGRBA06ODU  fa3a53156ae5c  1541030887     8  interaction item image
# 24  02HGRBA06ODU  fa3a53156ae5c  1541030887     9  interaction item image
# 25  02HGRBA06ODU  fa3a53156ae5c  1541030887    10  interaction item image
# 26  02HGRBA06ODU  fa3a53156ae5c  1541030897    11  interaction item image
# 27  02HGRBA06ODU  fa3a53156ae5c  1541030897    12  interaction item image
# 28  02HGRBA06ODU  fa3a53156ae5c  1541030897    13  interaction item image
# 29  02HGRBA06ODU  fa3a53156ae5c  1541030897    14  interaction item image
# 30  02HGRBA06ODU  fa3a53156ae5c  1541030897    15  interaction item image
# 31  02HGRBA06ODU  fa3a53156ae5c  1541030908    16  interaction item image
# 32  02HGRBA06ODU  fa3a53156ae5c  1541030908    17  interaction item image
# 33  02HGRBA06ODU  fa3a53156ae5c  1541030908    18  interaction item image
# 34  02HGRBA06ODU  fa3a53156ae5c  1541030908    19  interaction item image
# 35  02HGRBA06ODU  fa3a53156ae5c  1541030918    20  interaction item image
# 36  02HGRBA06ODU  fa3a53156ae5c  1541030918    21  interaction item image
#
#    reference platform               city  device current_filters impressions  \
# 1     666856       AU  Sydney, Australia  mobile             NaN         NaN
# 2     666856       AU  Sydney, Australia  mobile             NaN         NaN
# 3     666856       AU  Sydney, Australia  mobile             NaN         NaN
# 4     109038       AU  Sydney, Australia  mobile             NaN         NaN
# 5     666856       AU  Sydney, Australia  mobile             NaN         NaN
# 6     109038       AU  Sydney, Australia  mobile             NaN         NaN
# 7     666856       AU  Sydney, Australia  mobile             NaN         NaN
# 8     109038       AU  Sydney, Australia  mobile             NaN         NaN
# 9     109038       AU  Sydney, Australia  mobile             NaN         NaN
# 10    109038       AU  Sydney, Australia  mobile             NaN         NaN
# 11    109038       AU  Sydney, Australia  mobile             NaN         NaN
# 12    109038       AU  Sydney, Australia  mobile             NaN         NaN
# 17   3377332       BR    Ubatuba, Brazil  mobile             NaN         NaN
# 18   3377332       BR    Ubatuba, Brazil  mobile             NaN         NaN
# 21   3066244       BR    Ubatuba, Brazil  mobile             NaN         NaN
# 22   3066244       BR    Ubatuba, Brazil  mobile             NaN         NaN
# 23   3066244       BR    Ubatuba, Brazil  mobile             NaN         NaN
# 24   3066244       BR    Ubatuba, Brazil  mobile             NaN         NaN
# 25   3066244       BR    Ubatuba, Brazil  mobile             NaN         NaN
# 26   3066244       BR    Ubatuba, Brazil  mobile             NaN         NaN
# 27   3066244       BR    Ubatuba, Brazil  mobile             NaN         NaN
# 28   3066244       BR    Ubatuba, Brazil  mobile             NaN         NaN
# 29   3066244       BR    Ubatuba, Brazil  mobile             NaN         NaN
# 30   3066244       BR    Ubatuba, Brazil  mobile             NaN         NaN
# 31   3066244       BR    Ubatuba, Brazil  mobile             NaN         NaN
# 32   3066244       BR    Ubatuba, Brazil  mobile             NaN         NaN
# 33   3066244       BR    Ubatuba, Brazil  mobile             NaN         NaN
# 34   3066244       BR    Ubatuba, Brazil  mobile             NaN         NaN
# 35   3066244       BR    Ubatuba, Brazil  mobile             NaN         NaN
# 36   3066244       BR    Ubatuba, Brazil  mobile             NaN         NaN
#
#    prices
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN
# 10    NaN
# 11    NaN
# 12    NaN
# 17    NaN
# 18    NaN
# 21    NaN
# 22    NaN
# 23    NaN
# 24    NaN
# 25    NaN
# 26    NaN
# 27    NaN
# 28    NaN
# 29    NaN
# 30    NaN
# 31    NaN
# 32    NaN
# 33    NaN
# 34    NaN
# 35    NaN
# 36    NaN

# %%
train[['user_id', 'session_id', 'timestamp', 'city', 'reference', 'device']].duplicated().sum()
# Out:
# 9425134

# %%
test = load_data('test')

# %%
test[[col for col in test.columns if col!='step']].duplicated().sum()
# Out:
# 1986944

# %%
test.shape
# Out:
# (3782335, 12)

# %%
train[[col for col in train.columns if col!='step']].duplicated().sum()
# Out:
# 9249623

# %%
dups.shape
# Out:
# (9976106, 12)

# %%
train.shape
# Out:
# (15932992, 12)

# %%
9976106/15932992

# %%
9425134/15932992

# %%
train_grp = train.groupby('session_id')

# %%
a = train_grp['timestamp'].apply(lambda x: x.max() - x.min())

# %%
filepath = './cache/hotel_2vec'
check_dir(filepath)

# %%
a.describe()

# %%
def session_duration(ts):
    """
    Total session duration
    """
    if len(ts) == 1:
        return np.nan
    else:
        return ts.max() - ts.min()

    
def mean_dwell_time(ts):
    """
    Average dwell time
    """
    if len(ts) == 1:
        return np.nan
    else:
        return np.mean(np.diff(np.sort(ts)))

    
def median_dwell_time(ts):
    """
    Median dwell time
    """
    if len(ts) == 1:
        return np.nan
    else:
        return np.median(np.diff(np.sort(ts)))

    
def var_dwell_time(ts):
    """
    Variance of dewell time
    """
    if len(ts) == 1:
        return np.nan
    else:
        return np.var(np.diff(np.sort(ts)))
    
    
def dwell_time_prior_clickout(ts):
    """
    Duration before last clickout
    """
    if len(ts) == 1:
        return np.nan
    else:
        sorted_ts = np.sort(ts)
        return sorted_ts[-1] - sorted_ts[-2]
    
    
def dwell_time_prior_clickout_per(ts):
    """
    Percentage of last interaction dwell time before clickout
    """
    if len(ts) == 1:
        return np.nan
    else:
        sorted_ts = np.sort(ts)
        return (sorted_ts[-1] - sorted_ts[-2])/(sorted_ts[-1]-sorted_ts[0])

    
def second_last(x):
    """
    Get the seoncd last value
    """
    if len(x) == 1:
        return np.nan
    else:
        return x.iloc[-2]
    
    
def n_prev_clickouts(action_type):
    """
    Count how many previous clickouts are there
    """
    return (action_type.values == 'clickout item').sum() - 1


def avg_clickout_loc(action_type):
    """
    Average clickout location in the session
    """
    return np.mean(np.argwhere((action_type.values == 'clickout item'))+1)/len(x)



def compute_session_fts(df):
    """
    Create session features using groupby with agg
    """
    # define some aggs
    session_aggs = {'timestamp': [session_duration, mean_dwell_time, var_dwell_time, median_dwell_time, 
                                  dwell_time_prior_clickout, dwell_time_prior_clickout_per],
                    'step': ['max'],
                    'action_type': ['nunique', n_prev_clickouts, avg_clickout_loc, second_last],
                    'reference': ['nunique', second_last],
                    'city': ['last'],
                    'platform': ['last'],
                    'device': ['last'],
                    # below opeartes on createed features
                    'n_imps': ['last'],
                    'n_filters': ['last']}
    
    fprint = Fprint().fprint
    fprint("Generate length of 'impressions' and 'current_filters'")
    df['n_imps'] = df.impressions.str.split('|').str.len()
    df['n_filters'] = df.current_filters.str.split('|').str.len()
    
    fprint("Creating session features using agg on groupby from 'session_id'")
    session_grp = df.groupby('session_id')
    session_fts = session_grp.agg(session_aggs)
    fprint('Done creating session fts, cleaning up column names')
    session_fts.columns = ['_'.join(col).strip() for col in session_fts.columns.values]
    del df['n_imps'], df['n_filters']
    gc.collect()
    return session_fts
    
    
    

# def get_first(x):
#     return x.iloc[0]


# def get_last(x):
#     return x.iloc[-1]


# def n_clickouts(x):
#     # 'clickout item': 2
#     return (x.values == 2).sum()


# def click_rel_pos_avg(x):
#     # 'clickout item': 2
#     return np.mean(np.argwhere((x.values == 2)) + 1) / len(x)
