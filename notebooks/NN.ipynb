# %%
import pandas as pd
import numpy as np
import datetime
import time 
import os
import gc
import re
import sys
from functools import partial
from utils import ignore_warnings, load_data
from gensim.models import Word2Vec

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
# %%time
# nrows = 1000000
nrows = None
train = load_data('train', nrows=nrows)#, verbose=True)
# Out:
# CPU times: user 18.6 s, sys: 1.49 s, total: 20.1 s
# Wall time: 20.1 s

# %%
# select the rows that is clickout
is_clickout = train.action_type == 'clickout item'
# # and it is not nan
# not_na = train.re.notna()
# and the impressions are not nans
imp_not_na = train.impressions.notna()
# only select the ones with 25 lens 
train['nimp'] = train.impressions.str.split('|').str.len()
twenty_five = train['nimp'] == 25

select_mask = is_clickout & imp_not_na & twenty_five

# %%
train = train[select_mask].reset_index(drop=True)

# %%
train.loc[train['current_filters'].isna(), 'current_filters'] = 'no_filter'
train.loc[train['reference'].isna(), 'reference'] = 'no_reference'

train['cfs'] = train['current_filters'].str.split('|')
train['imps'] = train['impressions'].str.split('|')

# %%
train = train[['session_id', 'timestamp', 'reference', 'imps']]

# %%
train.shape
# Out:
# (1232016, 4)

# %%
def assign_target(row):
    ref = row.reference
    imp = row.imps
    if ref in imp:
        return imp.index(ref)
    else:
        return 25
#         return -1
train['target'] = train.apply(assign_target, axis=1)
# remove the target 25 (i.e. not appearing in the list)
print('before:', train.shape)
train = train[train.target != 25].reset_index(drop=True)
print('after:', train.shape)
# Out:
# before: (1232016, 5)
# after: (1231380, 5)

# %%
train.head()
# Out:
#       session_id   timestamp reference  \
# 0  aff3928535f48  1541037543    109038
# 1  aff3928535f48  1541038485   1257342
# 2  3599a6f709eab  1541063864   2795374
# 3  ec139e10b9238  1541100322   1032816
# 4  ec139e10b9238  1541100652   1032816
#
#                                                 imps  target
# 0  [3400638, 1253714, 3367857, 5100540, 1088584, ...       9
# 1  [55109, 129343, 54824, 2297972, 109014, 125734...       5
# 2  [2795374, 5582964, 1088390, 2781070, 1258068, ...       0
# 3  [12693, 46363, 81657, 18448, 47687, 152913, 18...      15
# 4  [12693, 46363, 81657, 18448, 47687, 152913, 18...      15

# %%
model = Word2Vec.load('./model.bin')

def encoding_depth(imps):
    return np.array([model[i] for i in imps])[None, :, :]

def encoding(imps):
    return np.array([model[i] for i in imps])

def encoding_column(imps):
    return np.array([model[i] for i in imps])[:, :, None]

# %%
# %%time
train['imps'] = train.imps.apply(encoding)
# Out:
# /home/sam/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   import sys
# CPU times: user 1min 40s, sys: 2.37 s, total: 1min 42s
# Wall time: 1min 42s

# %%
# all_imps = train.imps.values 
# all_imps = list(set([j for i in all_imps for j in i]))
# # we only embed the ones appeared in the impression list, otherwise uncomment below
# # all_imps = list(set(all_imps + list(train['reference'].unique())))
# imp2natural = {v: k for k, v in enumerate(all_imps)}
# # only select 25 length impressions 
# train['reference'] = train.reference.map(imp2natural)
# # drop the one reference does not have a mapping
# print('before:', train.shape)
# train = train[train.reference.notna()].reset_index(drop=True)
# print('after:', train.shape)
# train = train[train.imps.str.len()==25].reset_index(drop=True)
# train['imps'] = train.imps.apply(lambda x: [imp2natural[i] for i in x])
# def assign_target(row):
#     ref = row.reference
#     imp = row.imps
#     if ref in imp:
#         return imp.index(ref)
#     else:
#         return 25
# #         return -1
# train['target'] = train.apply(assign_target, axis=1)
# # remove the target 25 (i.e. not appearing in the list)
# print('before:', train.shape)
# train = train[train.target != 25].reset_index(drop=True)
# print('after:', train.shape)

# %%
train.imps[0].shape
# Out:
# (25, 100)

# %%
# len(imp2natural)

# %%
train = train[['session_id', 'imps', 'target']]

# %%
# split train and val
unique_sids = train['session_id'].unique()
train_sids = unique_sids[:-int(len(unique_sids)*0.1)]

# %%
trn_mask = train.session_id.isin(train_sids)
xtrain = train.loc[trn_mask, ['imps', 'target']].reset_index(drop=True)
xval = train.loc[~trn_mask, ['imps', 'target']].reset_index(drop=True)
del train

# %%
print(xtrain.shape, xval.shape)
# Out:
# (1108640, 2) (122740, 2)

# %%
ytrain = xtrain['target'].values
yval = xval['target'].values
del xtrain['target'], xval['target']

# %%
from keras.models import Sequential
from keras.layers import Dense, Conv1D, Conv2D, Flatten, Dropout, BatchNormalization
#create model
model = Sequential()
#add model layers
# model.add(Conv2D(64, kernel_size=3, activation='relu', input_shape=(1, 25, 100)))
# model.add(Conv2D(32, kernel_size=3, activation='relu'))
model.add(Conv1D(16, kernel_size=3, activation='relu', input_shape=(25, 100)))
model.add(BatchNormalization())
model.add(Conv1D(32, kernel_size=3, activation='relu'))
model.add(BatchNormalization())
model.add(Conv1D(32, kernel_size=3, activation='relu'))
model.add(BatchNormalization())
model.add(Conv1D(32, kernel_size=3, activation='relu'))
model.add(BatchNormalization())
model.add(Flatten())
model.add(Dropout(0.2))
model.add(Dense(25, activation='softmax'))
# Out:
# Using TensorFlow backend.

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_1 (Conv1D)            (None, 23, 16)            4816
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 23, 16)            64
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 21, 32)            1568
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 21, 32)            128
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 19, 32)            3104
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 19, 32)            128
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 17, 32)            3104
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 17, 32)            128
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 544)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 544)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 25)                13625
# =================================================================
# Total params: 26,665
# Trainable params: 26,441
# Non-trainable params: 224
# _________________________________________________________________

# %%
len(xtrain)
# Out:
# 1108640

# %%
from keras import optimizers
# opt = optimizers.SGD(lr = 0.001, decay = 1e-6, momentum = 0.9, nesterov = True)
opt = optimizers.Adam(lr=0.001)
model.compile(optimizer = opt, loss = "categorical_crossentropy", metrics=['accuracy'])
# model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# from clr import CyclicLR
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau, TensorBoard
from datetime import datetime as dt
model_file = 'conv1d.model'

callbacks = [ModelCheckpoint(model_file, save_best_only=True, verbose=1)]
callbacks.append(EarlyStopping(patience=100, verbose=1))
callbacks.append(ReduceLROnPlateau(factor=0.5, patience=50, min_lr=5e-4, verbose=1))
log_dir = "logs/{}".format(dt.now().strftime('%m-%d-%H-%M'))
# tb = TensorBoard(log_dir=log_dir, histogram_freq=2, write_graph=True, write_grads=True, write_images=True,
#                  embeddings_freq=10, embeddings_layer_names=['embedding_1'], embeddings_data=next(val_gen))
tb = TensorBoard(log_dir=log_dir, write_graph=True, write_grads=True)
callbacks.append(tb)

# %%
batch_size = 128
n_epochs = 3000
# keras requires 0, 1 binary label input
from keras.utils import to_categorical
train_y_binary = to_categorical(ytrain)
val_y_binary = to_categorical(yval)

# %%
assert train_y_binary.shape[1] == val_y_binary.shape[1]

# %%
t_int = time.time()
history = model.fit(np.array(xtrain.imps.tolist()), 
                    train_y_binary, 
                    epochs=n_epochs, 
                    batch_size=batch_size,
                    validation_data=(np.array(xval.imps.tolist()), val_y_binary),
                    verbose = 2, 
                    shuffle = True,
                   callbacks=callbacks)
print(f'total time took: {(time.time()-t_int)/60:.2f}mins')
# Out:
# Train on 1108640 samples, validate on 122740 samples
# Epoch 1/3000
#  - 48s - loss: 2.6485 - acc: 0.3218 - val_loss: 2.5961 - val_acc: 0.3261
#
# Epoch 00001: val_loss improved from inf to 2.59611, saving model to conv1d.model
# Epoch 2/3000
#  - 46s - loss: 2.5930 - acc: 0.3263 - val_loss: 2.5882 - val_acc: 0.3261
#
# Epoch 00002: val_loss improved from 2.59611 to 2.58817, saving model to conv1d.model
# Epoch 3/3000
#  - 45s - loss: 2.5859 - acc: 0.3263 - val_loss: 2.5836 - val_acc: 0.3261
#
# Epoch 00003: val_loss improved from 2.58817 to 2.58355, saving model to conv1d.model
# Epoch 4/3000
#  - 45s - loss: 2.5823 - acc: 0.3263 - val_loss: 2.5818 - val_acc: 0.3261
#
# Epoch 00004: val_loss improved from 2.58355 to 2.58183, saving model to conv1d.model
# Epoch 5/3000
#  - 46s - loss: 2.5794 - acc: 0.3263 - val_loss: 2.5793 - val_acc: 0.3261
#
# Epoch 00005: val_loss improved from 2.58183 to 2.57928, saving model to conv1d.model
# Epoch 6/3000
#  - 45s - loss: 2.5775 - acc: 0.3263 - val_loss: 2.5777 - val_acc: 0.3260
#
# Epoch 00006: val_loss improved from 2.57928 to 2.57772, saving model to conv1d.model
# Epoch 7/3000
#  - 46s - loss: 2.5757 - acc: 0.3263 - val_loss: 2.5778 - val_acc: 0.3260
#
# Epoch 00007: val_loss did not improve from 2.57772
# Epoch 8/3000
#  - 46s - loss: 2.5741 - acc: 0.3263 - val_loss: 2.5766 - val_acc: 0.3262
#
# Epoch 00008: val_loss improved from 2.57772 to 2.57656, saving model to conv1d.model
# Epoch 9/3000
#  - 46s - loss: 2.5729 - acc: 0.3263 - val_loss: 2.5766 - val_acc: 0.3262
#
# Epoch 00009: val_loss did not improve from 2.57656
# Epoch 10/3000
#  - 46s - loss: 2.5715 - acc: 0.3263 - val_loss: 2.5755 - val_acc: 0.3260
#
# Epoch 00010: val_loss improved from 2.57656 to 2.57554, saving model to conv1d.model
# Epoch 11/3000
#  - 45s - loss: 2.5707 - acc: 0.3263 - val_loss: 2.5758 - val_acc: 0.3262
#
# Epoch 00011: val_loss did not improve from 2.57554
# Epoch 12/3000
#  - 45s - loss: 2.5699 - acc: 0.3263 - val_loss: 2.5753 - val_acc: 0.3261
#
# Epoch 00012: val_loss improved from 2.57554 to 2.57533, saving model to conv1d.model
# Epoch 13/3000
#  - 45s - loss: 2.5688 - acc: 0.3262 - val_loss: 2.5742 - val_acc: 0.3258
#
# Epoch 00013: val_loss improved from 2.57533 to 2.57423, saving model to conv1d.model
# Epoch 14/3000
#  - 45s - loss: 2.5682 - acc: 0.3263 - val_loss: 2.5767 - val_acc: 0.3258
#
# Epoch 00014: val_loss did not improve from 2.57423
# Epoch 15/3000
#  - 45s - loss: 2.5674 - acc: 0.3263 - val_loss: 2.5728 - val_acc: 0.3261
#
# Epoch 00015: val_loss improved from 2.57423 to 2.57282, saving model to conv1d.model
# Epoch 16/3000
#  - 45s - loss: 2.5667 - acc: 0.3262 - val_loss: 2.5746 - val_acc: 0.3261
#
# Epoch 00016: val_loss did not improve from 2.57282
# Epoch 17/3000
#  - 45s - loss: 2.5663 - acc: 0.3263 - val_loss: 2.5740 - val_acc: 0.3261
#
# Epoch 00017: val_loss did not improve from 2.57282
# Epoch 18/3000
#  - 45s - loss: 2.5659 - acc: 0.3262 - val_loss: 2.5737 - val_acc: 0.3258
#
# Epoch 00018: val_loss did not improve from 2.57282
# Epoch 19/3000
#  - 45s - loss: 2.5652 - acc: 0.3263 - val_loss: 2.5715 - val_acc: 0.3260
#
# Epoch 00019: val_loss improved from 2.57282 to 2.57153, saving model to conv1d.model
# Epoch 20/3000
#  - 45s - loss: 2.5646 - acc: 0.3263 - val_loss: 2.5715 - val_acc: 0.3262
#
# Epoch 00020: val_loss improved from 2.57153 to 2.57148, saving model to conv1d.model
# Epoch 21/3000
#  - 45s - loss: 2.5643 - acc: 0.3263 - val_loss: 2.5719 - val_acc: 0.3261
#
# Epoch 00021: val_loss did not improve from 2.57148
# Epoch 22/3000
#  - 45s - loss: 2.5640 - acc: 0.3262 - val_loss: 2.5756 - val_acc: 0.3260
#
# Epoch 00022: val_loss did not improve from 2.57148
# Epoch 23/3000
#  - 45s - loss: 2.5634 - acc: 0.3263 - val_loss: 2.5708 - val_acc: 0.3261
#
# Epoch 00023: val_loss improved from 2.57148 to 2.57081, saving model to conv1d.model
# Epoch 24/3000
#  - 45s - loss: 2.5631 - acc: 0.3263 - val_loss: 2.5713 - val_acc: 0.3260
#
# Epoch 00024: val_loss did not improve from 2.57081
# Epoch 25/3000
#  - 45s - loss: 2.5625 - acc: 0.3263 - val_loss: 2.5739 - val_acc: 0.3261
#
# Epoch 00025: val_loss did not improve from 2.57081
# Epoch 26/3000
#  - 45s - loss: 2.5621 - acc: 0.3263 - val_loss: 2.5722 - val_acc: 0.3255
#
# Epoch 00026: val_loss did not improve from 2.57081
# Epoch 27/3000
#  - 45s - loss: 2.5617 - acc: 0.3263 - val_loss: 2.5708 - val_acc: 0.3259
#
# Epoch 00027: val_loss improved from 2.57081 to 2.57079, saving model to conv1d.model
# Epoch 28/3000
#  - 45s - loss: 2.5616 - acc: 0.3262 - val_loss: 2.5715 - val_acc: 0.3259
#
# Epoch 00028: val_loss did not improve from 2.57079
# Epoch 29/3000
#  - 45s - loss: 2.5614 - acc: 0.3263 - val_loss: 2.5703 - val_acc: 0.3260
#
# Epoch 00029: val_loss improved from 2.57079 to 2.57027, saving model to conv1d.model
# Epoch 30/3000
#  - 45s - loss: 2.5610 - acc: 0.3263 - val_loss: 2.5722 - val_acc: 0.3251
#
# Epoch 00030: val_loss did not improve from 2.57027
# Epoch 31/3000
#  - 45s - loss: 2.5606 - acc: 0.3263 - val_loss: 2.5709 - val_acc: 0.3260
#
# Epoch 00031: val_loss did not improve from 2.57027
# Epoch 32/3000
#  - 45s - loss: 2.5603 - acc: 0.3264 - val_loss: 2.5712 - val_acc: 0.3257
#
# Epoch 00032: val_loss did not improve from 2.57027
# Epoch 33/3000
#  - 45s - loss: 2.5599 - acc: 0.3263 - val_loss: 2.5707 - val_acc: 0.3259
#
# Epoch 00033: val_loss did not improve from 2.57027
# Epoch 34/3000
#  - 45s - loss: 2.5595 - acc: 0.3263 - val_loss: 2.5705 - val_acc: 0.3257
#
# Epoch 00034: val_loss did not improve from 2.57027
# Epoch 35/3000
#  - 45s - loss: 2.5596 - acc: 0.3262 - val_loss: 2.5707 - val_acc: 0.3259
#
# Epoch 00035: val_loss did not improve from 2.57027
# Epoch 36/3000
#  - 45s - loss: 2.5590 - acc: 0.3263 - val_loss: 2.5714 - val_acc: 0.3255
#
# Epoch 00036: val_loss did not improve from 2.57027
# Epoch 37/3000
#  - 45s - loss: 2.5589 - acc: 0.3262 - val_loss: 2.5690 - val_acc: 0.3261
#
# Epoch 00037: val_loss improved from 2.57027 to 2.56905, saving model to conv1d.model
# Epoch 38/3000
#  - 46s - loss: 2.5586 - acc: 0.3263 - val_loss: 2.5709 - val_acc: 0.3258
#
# Epoch 00038: val_loss did not improve from 2.56905
# Epoch 39/3000
#  - 45s - loss: 2.5585 - acc: 0.3263 - val_loss: 2.5693 - val_acc: 0.3260
#
# Epoch 00039: val_loss did not improve from 2.56905
# Epoch 40/3000
#  - 45s - loss: 2.5583 - acc: 0.3263 - val_loss: 2.5731 - val_acc: 0.3258
#
# Epoch 00040: val_loss did not improve from 2.56905
# Epoch 41/3000
#  - 45s - loss: 2.5581 - acc: 0.3263 - val_loss: 2.5696 - val_acc: 0.3258
#
# Epoch 00041: val_loss did not improve from 2.56905
# Epoch 42/3000
#  - 45s - loss: 2.5576 - acc: 0.3263 - val_loss: 2.5705 - val_acc: 0.3259
#
# Epoch 00042: val_loss did not improve from 2.56905
# Epoch 43/3000
#  - 45s - loss: 2.5575 - acc: 0.3263 - val_loss: 2.5699 - val_acc: 0.3261
#
# Epoch 00043: val_loss did not improve from 2.56905
# Epoch 44/3000
#  - 45s - loss: 2.5574 - acc: 0.3263 - val_loss: 2.5696 - val_acc: 0.3257
#
# Epoch 00044: val_loss did not improve from 2.56905
# Epoch 45/3000
#  - 45s - loss: 2.5572 - acc: 0.3263 - val_loss: 2.5695 - val_acc: 0.3260
#
# Epoch 00045: val_loss did not improve from 2.56905
# Epoch 46/3000
#  - 45s - loss: 2.5570 - acc: 0.3263 - val_loss: 2.5693 - val_acc: 0.3259
#
# Epoch 00046: val_loss did not improve from 2.56905
# Epoch 47/3000
#  - 45s - loss: 2.5568 - acc: 0.3263 - val_loss: 2.5693 - val_acc: 0.3259
#
# Epoch 00047: val_loss did not improve from 2.56905
# Epoch 48/3000
#  - 45s - loss: 2.5568 - acc: 0.3263 - val_loss: 2.5697 - val_acc: 0.3259
#
# Epoch 00048: val_loss did not improve from 2.56905
# Epoch 49/3000
#  - 45s - loss: 2.5561 - acc: 0.3263 - val_loss: 2.5707 - val_acc: 0.3254
#
# Epoch 00049: val_loss did not improve from 2.56905
# Epoch 50/3000
#  - 45s - loss: 2.5563 - acc: 0.3263 - val_loss: 2.5705 - val_acc: 0.3259
#
# Epoch 00050: val_loss did not improve from 2.56905
# Epoch 51/3000
#  - 45s - loss: 2.5561 - acc: 0.3263 - val_loss: 2.5691 - val_acc: 0.3260
#
# Epoch 00051: val_loss did not improve from 2.56905
# Epoch 52/3000
#  - 45s - loss: 2.5558 - acc: 0.3263 - val_loss: 2.5695 - val_acc: 0.3261
#
# Epoch 00052: val_loss did not improve from 2.56905
# Epoch 53/3000
#  - 45s - loss: 2.5558 - acc: 0.3263 - val_loss: 2.5724 - val_acc: 0.3260
#
# Epoch 00053: val_loss did not improve from 2.56905
# Epoch 54/3000
#  - 45s - loss: 2.5557 - acc: 0.3263 - val_loss: 2.5692 - val_acc: 0.3259
#
# Epoch 00054: val_loss did not improve from 2.56905
# Epoch 55/3000
#  - 45s - loss: 2.5553 - acc: 0.3264 - val_loss: 2.5681 - val_acc: 0.3259
# Epoch 00055: val_loss improved from 2.56905 to 2.56808, saving model to conv1d.model
# Epoch 56/3000
#  - 45s - loss: 2.5551 - acc: 0.3263 - val_loss: 2.5716 - val_acc: 0.3260
#
# Epoch 00056: val_loss did not improve from 2.56808
# Epoch 57/3000
#  - 45s - loss: 2.5551 - acc: 0.3263 - val_loss: 2.5701 - val_acc: 0.3259
#
# Epoch 00057: val_loss did not improve from 2.56808
# Epoch 58/3000
#  - 45s - loss: 2.5549 - acc: 0.3263 - val_loss: 2.5675 - val_acc: 0.3259
#
# Epoch 00058: val_loss improved from 2.56808 to 2.56753, saving model to conv1d.model
# Epoch 59/3000
#  - 45s - loss: 2.5548 - acc: 0.3263 - val_loss: 2.5695 - val_acc: 0.3259
#
# Epoch 00059: val_loss did not improve from 2.56753
# Epoch 60/3000
#  - 45s - loss: 2.5548 - acc: 0.3263 - val_loss: 2.5687 - val_acc: 0.3260
#
# Epoch 00060: val_loss did not improve from 2.56753
# Epoch 61/3000
#  - 45s - loss: 2.5545 - acc: 0.3263 - val_loss: 2.5687 - val_acc: 0.3261
#
# Epoch 00061: val_loss did not improve from 2.56753
# Epoch 62/3000
#  - 45s - loss: 2.5546 - acc: 0.3263 - val_loss: 2.5696 - val_acc: 0.3261
#
# Epoch 00062: val_loss did not improve from 2.56753
# Epoch 63/3000
#  - 45s - loss: 2.5540 - acc: 0.3263 - val_loss: 2.5689 - val_acc: 0.3259
#
# Epoch 00063: val_loss did not improve from 2.56753
# Epoch 64/3000
#  - 45s - loss: 2.5539 - acc: 0.3263 - val_loss: 2.5683 - val_acc: 0.3259
#
# Epoch 00064: val_loss did not improve from 2.56753
# Epoch 65/3000
#  - 45s - loss: 2.5539 - acc: 0.3262 - val_loss: 2.5687 - val_acc: 0.3258
#
# Epoch 00065: val_loss did not improve from 2.56753
# Epoch 66/3000
#  - 45s - loss: 2.5538 - acc: 0.3263 - val_loss: 2.5680 - val_acc: 0.3260
#
# Epoch 00066: val_loss did not improve from 2.56753
# Epoch 67/3000
#  - 45s - loss: 2.5536 - acc: 0.3263 - val_loss: 2.5685 - val_acc: 0.3257
#
# Epoch 00067: val_loss did not improve from 2.56753
# Epoch 68/3000
#  - 45s - loss: 2.5537 - acc: 0.3263 - val_loss: 2.5686 - val_acc: 0.3257
#
# Epoch 00068: val_loss did not improve from 2.56753
# Epoch 69/3000
#  - 45s - loss: 2.5534 - acc: 0.3263 - val_loss: 2.5680 - val_acc: 0.3260
#
# Epoch 00069: val_loss did not improve from 2.56753
# Epoch 70/3000
#  - 45s - loss: 2.5534 - acc: 0.3263 - val_loss: 2.5707 - val_acc: 0.3251
#
# Epoch 00070: val_loss did not improve from 2.56753
# Epoch 71/3000
#  - 45s - loss: 2.5532 - acc: 0.3262 - val_loss: 2.5698 - val_acc: 0.3259
#
# Epoch 00071: val_loss did not improve from 2.56753
# Epoch 72/3000
#  - 45s - loss: 2.5530 - acc: 0.3263 - val_loss: 2.5691 - val_acc: 0.3256
#
# Epoch 00072: val_loss did not improve from 2.56753
# Epoch 73/3000
#  - 45s - loss: 2.5532 - acc: 0.3263 - val_loss: 2.5686 - val_acc: 0.3259
#
# Epoch 00073: val_loss did not improve from 2.56753
# Epoch 74/3000
#  - 45s - loss: 2.5533 - acc: 0.3262 - val_loss: 2.5672 - val_acc: 0.3262
#
# Epoch 00074: val_loss improved from 2.56753 to 2.56716, saving model to conv1d.model
# Epoch 75/3000
#  - 45s - loss: 2.5528 - acc: 0.3263 - val_loss: 2.5696 - val_acc: 0.3258
#
# Epoch 00075: val_loss did not improve from 2.56716
# Epoch 76/3000
#  - 45s - loss: 2.5528 - acc: 0.3264 - val_loss: 2.5691 - val_acc: 0.3261
#
# Epoch 00076: val_loss did not improve from 2.56716
# Epoch 77/3000
#  - 45s - loss: 2.5527 - acc: 0.3263 - val_loss: 2.5688 - val_acc: 0.3260
#
# Epoch 00077: val_loss did not improve from 2.56716
# Epoch 78/3000
#  - 45s - loss: 2.5527 - acc: 0.3263 - val_loss: 2.5678 - val_acc: 0.3262
#
# Epoch 00078: val_loss did not improve from 2.56716
# Epoch 79/3000
#  - 45s - loss: 2.5528 - acc: 0.3263 - val_loss: 2.5690 - val_acc: 0.3253
#
# Epoch 00079: val_loss did not improve from 2.56716
# Epoch 80/3000
#  - 45s - loss: 2.5522 - acc: 0.3263 - val_loss: 2.5684 - val_acc: 0.3260
#
# Epoch 00080: val_loss did not improve from 2.56716
# Epoch 81/3000
#  - 45s - loss: 2.5524 - acc: 0.3263 - val_loss: 2.5700 - val_acc: 0.3255
#
# Epoch 00081: val_loss did not improve from 2.56716
# Epoch 82/3000
#  - 45s - loss: 2.5520 - acc: 0.3263 - val_loss: 2.5690 - val_acc: 0.3259
#
# Epoch 00082: val_loss did not improve from 2.56716
# Epoch 83/3000
#  - 45s - loss: 2.5521 - acc: 0.3263 - val_loss: 2.5737 - val_acc: 0.3254
#
# Epoch 00083: val_loss did not improve from 2.56716
# Epoch 84/3000
#  - 45s - loss: 2.5520 - acc: 0.3263 - val_loss: 2.5689 - val_acc: 0.3260
#
# Epoch 00084: val_loss did not improve from 2.56716
# Epoch 85/3000
#  - 45s - loss: 2.5518 - acc: 0.3264 - val_loss: 2.5682 - val_acc: 0.3261
#
# Epoch 00085: val_loss did not improve from 2.56716
# Epoch 86/3000
#  - 46s - loss: 2.5517 - acc: 0.3263 - val_loss: 2.5697 - val_acc: 0.3262
#
# Epoch 00086: val_loss did not improve from 2.56716
# Epoch 87/3000
#  - 45s - loss: 2.5518 - acc: 0.3263 - val_loss: 2.5687 - val_acc: 0.3260
#
# Epoch 00087: val_loss did not improve from 2.56716
# Epoch 88/3000
#  - 45s - loss: 2.5515 - acc: 0.3263 - val_loss: 2.5698 - val_acc: 0.3257
#
# Epoch 00088: val_loss did not improve from 2.56716
# Epoch 89/3000
#  - 45s - loss: 2.5513 - acc: 0.3263 - val_loss: 2.5695 - val_acc: 0.3256
#
# Epoch 00089: val_loss did not improve from 2.56716
# Epoch 90/3000
#  - 45s - loss: 2.5514 - acc: 0.3262 - val_loss: 2.5683 - val_acc: 0.3262
#
# Epoch 00090: val_loss did not improve from 2.56716
# Epoch 91/3000
#  - 45s - loss: 2.5514 - acc: 0.3262 - val_loss: 2.5692 - val_acc: 0.3259
#
# Epoch 00091: val_loss did not improve from 2.56716
# Epoch 92/3000
#  - 45s - loss: 2.5512 - acc: 0.3264 - val_loss: 2.5692 - val_acc: 0.3255
#
# Epoch 00092: val_loss did not improve from 2.56716
# Epoch 93/3000
#  - 45s - loss: 2.5510 - acc: 0.3263 - val_loss: 2.5691 - val_acc: 0.3260
#
# Epoch 00093: val_loss did not improve from 2.56716
# Epoch 94/3000
#  - 46s - loss: 2.5511 - acc: 0.3264 - val_loss: 2.5693 - val_acc: 0.3259
#
# Epoch 00094: val_loss did not improve from 2.56716
# Epoch 95/3000
#  - 45s - loss: 2.5507 - acc: 0.3263 - val_loss: 2.5690 - val_acc: 0.3258
#
# Epoch 00095: val_loss did not improve from 2.56716
# Epoch 96/3000
#  - 45s - loss: 2.5510 - acc: 0.3263 - val_loss: 2.5680 - val_acc: 0.3260
#
# Epoch 00096: val_loss did not improve from 2.56716
# Epoch 97/3000
#  - 45s - loss: 2.5508 - acc: 0.3263 - val_loss: 2.5705 - val_acc: 0.3259
#
# Epoch 00097: val_loss did not improve from 2.56716
# Epoch 98/3000
#  - 45s - loss: 2.5507 - acc: 0.3263 - val_loss: 2.5684 - val_acc: 0.3259
#
# Epoch 00098: val_loss did not improve from 2.56716
# Epoch 99/3000
#  - 45s - loss: 2.5507 - acc: 0.3264 - val_loss: 2.5689 - val_acc: 0.3258
#
# Epoch 00099: val_loss did not improve from 2.56716
# Epoch 100/3000
#  - 45s - loss: 2.5507 - acc: 0.3263 - val_loss: 2.5686 - val_acc: 0.3259
#
# Epoch 00100: val_loss did not improve from 2.56716
# Epoch 101/3000
#  - 45s - loss: 2.5505 - acc: 0.3264 - val_loss: 2.5687 - val_acc: 0.3258
#
# Epoch 00101: val_loss did not improve from 2.56716
# Epoch 102/3000
#  - 45s - loss: 2.5505 - acc: 0.3263 - val_loss: 2.5689 - val_acc: 0.3255
#
# Epoch 00102: val_loss did not improve from 2.56716
# Epoch 103/3000
#  - 45s - loss: 2.5505 - acc: 0.3263 - val_loss: 2.5682 - val_acc: 0.3258
#
# Epoch 00103: val_loss did not improve from 2.56716
# Epoch 104/3000
#  - 45s - loss: 2.5503 - acc: 0.3263 - val_loss: 2.5699 - val_acc: 0.3258
#
# Epoch 00104: val_loss did not improve from 2.56716
# Epoch 105/3000
#  - 45s - loss: 2.5503 - acc: 0.3263 - val_loss: 2.5693 - val_acc: 0.3258
#
# Epoch 00105: val_loss did not improve from 2.56716
# Epoch 106/3000
#  - 45s - loss: 2.5501 - acc: 0.3263 - val_loss: 2.5686 - val_acc: 0.3259
#
# Epoch 00106: val_loss did not improve from 2.56716
# Epoch 107/3000
#  - 45s - loss: 2.5501 - acc: 0.3263 - val_loss: 2.5694 - val_acc: 0.3254
#
# Epoch 00107: val_loss did not improve from 2.56716
# Epoch 108/3000
#  - 45s - loss: 2.5501 - acc: 0.3263 - val_loss: 2.5687 - val_acc: 0.3256
#
# Epoch 00108: val_loss did not improve from 2.56716
# Epoch 109/3000
#  - 45s - loss: 2.5503 - acc: 0.3263 - val_loss: 2.5690 - val_acc: 0.3260
#
# Epoch 00109: val_loss did not improve from 2.56716
# Epoch 110/3000
#  - 45s - loss: 2.5497 - acc: 0.3263 - val_loss: 2.5696 - val_acc: 0.3257
#
# Epoch 00110: val_loss did not improve from 2.56716
# Epoch 111/3000
#  - 45s - loss: 2.5498 - acc: 0.3263 - val_loss: 2.5688 - val_acc: 0.3258
#
# Epoch 00111: val_loss did not improve from 2.56716
# Epoch 112/3000
#  - 45s - loss: 2.5498 - acc: 0.3263 - val_loss: 2.5706 - val_acc: 0.3258
#
# Epoch 00112: val_loss did not improve from 2.56716
# Epoch 113/3000
#  - 45s - loss: 2.5496 - acc: 0.3263 - val_loss: 2.5693 - val_acc: 0.3263
#
# Epoch 00113: val_loss did not improve from 2.56716
# Epoch 114/3000
#  - 45s - loss: 2.5497 - acc: 0.3263 - val_loss: 2.5686 - val_acc: 0.3261
#
# Epoch 00114: val_loss did not improve from 2.56716
# Epoch 115/3000
#  - 45s - loss: 2.5494 - acc: 0.3264 - val_loss: 2.5697 - val_acc: 0.3263
#
# Epoch 00115: val_loss did not improve from 2.56716
# Epoch 116/3000
#  - 45s - loss: 2.5495 - acc: 0.3263 - val_loss: 2.5687 - val_acc: 0.3260
#
# Epoch 00116: val_loss did not improve from 2.56716
# Epoch 117/3000
#  - 46s - loss: 2.5494 - acc: 0.3263 - val_loss: 2.5694 - val_acc: 0.3260
#
# Epoch 00117: val_loss did not improve from 2.56716
# Epoch 118/3000
#  - 45s - loss: 2.5494 - acc: 0.3263 - val_loss: 2.5688 - val_acc: 0.3260
#
# Epoch 00118: val_loss did not improve from 2.56716
# Epoch 119/3000
#  - 45s - loss: 2.5491 - acc: 0.3263 - val_loss: 2.5682 - val_acc: 0.3261
#
# Epoch 00119: val_loss did not improve from 2.56716
# Epoch 120/3000
#  - 45s - loss: 2.5491 - acc: 0.3263 - val_loss: 2.5674 - val_acc: 0.3258
#
# Epoch 00120: val_loss did not improve from 2.56716
# Epoch 121/3000
#  - 45s - loss: 2.5494 - acc: 0.3263 - val_loss: 2.5688 - val_acc: 0.3254
#
# Epoch 00121: val_loss did not improve from 2.56716
# Epoch 122/3000
#  - 45s - loss: 2.5489 - acc: 0.3262 - val_loss: 2.5673 - val_acc: 0.3257
#
# Epoch 00122: val_loss did not improve from 2.56716
# Epoch 123/3000
#  - 45s - loss: 2.5489 - acc: 0.3264 - val_loss: 2.5687 - val_acc: 0.3252
#
# Epoch 00123: val_loss did not improve from 2.56716
# Epoch 124/3000
#  - 45s - loss: 2.5492 - acc: 0.3263 - val_loss: 2.5677 - val_acc: 0.3261
#
# Epoch 00124: val_loss did not improve from 2.56716
#
# Epoch 00124: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 125/3000
#  - 45s - loss: 2.5452 - acc: 0.3264 - val_loss: 2.5670 - val_acc: 0.3259
#
# Epoch 00125: val_loss improved from 2.56716 to 2.56703, saving model to conv1d.model
# Epoch 126/3000
#  - 45s - loss: 2.5445 - acc: 0.3264 - val_loss: 2.5665 - val_acc: 0.3260
#
# Epoch 00126: val_loss improved from 2.56703 to 2.56652, saving model to conv1d.model
# Epoch 127/3000
#  - 45s - loss: 2.5441 - acc: 0.3263 - val_loss: 2.5671 - val_acc: 0.3260
#
# Epoch 00127: val_loss did not improve from 2.56652
# Epoch 128/3000
#  - 45s - loss: 2.5443 - acc: 0.3263 - val_loss: 2.5678 - val_acc: 0.3257
#
# Epoch 00128: val_loss did not improve from 2.56652
# Epoch 129/3000
#  - 45s - loss: 2.5441 - acc: 0.3263 - val_loss: 2.5667 - val_acc: 0.3261
#
# Epoch 00129: val_loss did not improve from 2.56652
# Epoch 130/3000
#  - 45s - loss: 2.5440 - acc: 0.3262 - val_loss: 2.5667 - val_acc: 0.3259
#
# Epoch 00130: val_loss did not improve from 2.56652
# Epoch 131/3000
#  - 45s - loss: 2.5438 - acc: 0.3264 - val_loss: 2.5675 - val_acc: 0.3259
#
# Epoch 00131: val_loss did not improve from 2.56652
# Epoch 132/3000
#  - 45s - loss: 2.5438 - acc: 0.3263 - val_loss: 2.5668 - val_acc: 0.3259
#
# Epoch 00132: val_loss did not improve from 2.56652
# Epoch 133/3000
#  - 45s - loss: 2.5440 - acc: 0.3263 - val_loss: 2.5668 - val_acc: 0.3260
#
# Epoch 00133: val_loss did not improve from 2.56652
# Epoch 134/3000
#  - 45s - loss: 2.5435 - acc: 0.3263 - val_loss: 2.5669 - val_acc: 0.3260
#
# Epoch 00134: val_loss did not improve from 2.56652
# Epoch 135/3000
#  - 45s - loss: 2.5440 - acc: 0.3263 - val_loss: 2.5689 - val_acc: 0.3254
#
# Epoch 00135: val_loss did not improve from 2.56652
# Epoch 136/3000
#  - 45s - loss: 2.5439 - acc: 0.3262 - val_loss: 2.5664 - val_acc: 0.3258
#
# Epoch 00136: val_loss improved from 2.56652 to 2.56639, saving model to conv1d.model
# Epoch 137/3000
#  - 45s - loss: 2.5436 - acc: 0.3263 - val_loss: 2.5680 - val_acc: 0.3256
#
# Epoch 00137: val_loss did not improve from 2.56639
# Epoch 138/3000
#  - 45s - loss: 2.5439 - acc: 0.3264 - val_loss: 2.5676 - val_acc: 0.3257
#
# Epoch 00138: val_loss did not improve from 2.56639
# Epoch 139/3000
#  - 45s - loss: 2.5437 - acc: 0.3263 - val_loss: 2.5684 - val_acc: 0.3256
#
# Epoch 00139: val_loss did not improve from 2.56639
# Epoch 140/3000
#  - 45s - loss: 2.5435 - acc: 0.3264 - val_loss: 2.5667 - val_acc: 0.3256
#
# Epoch 00140: val_loss did not improve from 2.56639
# Epoch 141/3000
#  - 45s - loss: 2.5435 - acc: 0.3262 - val_loss: 2.5675 - val_acc: 0.3259
#
# Epoch 00141: val_loss did not improve from 2.56639
# Epoch 142/3000
#  - 45s - loss: 2.5434 - acc: 0.3264 - val_loss: 2.5666 - val_acc: 0.3261
#
# Epoch 00142: val_loss did not improve from 2.56639
# Epoch 143/3000
#  - 45s - loss: 2.5434 - acc: 0.3263 - val_loss: 2.5676 - val_acc: 0.3262
#
# Epoch 00143: val_loss did not improve from 2.56639
# Epoch 144/3000
#  - 45s - loss: 2.5434 - acc: 0.3263 - val_loss: 2.5679 - val_acc: 0.3258
#
# Epoch 00144: val_loss did not improve from 2.56639
# Epoch 145/3000
#  - 45s - loss: 2.5435 - acc: 0.3263 - val_loss: 2.5670 - val_acc: 0.3260
#
# Epoch 00145: val_loss did not improve from 2.56639
# Epoch 146/3000
#  - 45s - loss: 2.5435 - acc: 0.3264 - val_loss: 2.5668 - val_acc: 0.3259
#
# Epoch 00146: val_loss did not improve from 2.56639
# Epoch 147/3000
#  - 45s - loss: 2.5437 - acc: 0.3263 - val_loss: 2.5669 - val_acc: 0.3257
#
# Epoch 00147: val_loss did not improve from 2.56639
# Epoch 148/3000
#  - 45s - loss: 2.5434 - acc: 0.3263 - val_loss: 2.5670 - val_acc: 0.3257
#
# Epoch 00148: val_loss did not improve from 2.56639
# Epoch 149/3000
#  - 45s - loss: 2.5435 - acc: 0.3264 - val_loss: 2.5672 - val_acc: 0.3260
#
# Epoch 00149: val_loss did not improve from 2.56639
# Epoch 150/3000
#  - 45s - loss: 2.5434 - acc: 0.3263 - val_loss: 2.5670 - val_acc: 0.3260
#
# Epoch 00150: val_loss did not improve from 2.56639
# Epoch 151/3000
#  - 45s - loss: 2.5434 - acc: 0.3263 - val_loss: 2.5679 - val_acc: 0.3256
#
# Epoch 00151: val_loss did not improve from 2.56639
# Epoch 152/3000
#  - 45s - loss: 2.5433 - acc: 0.3263 - val_loss: 2.5675 - val_acc: 0.3257
#
# Epoch 00152: val_loss did not improve from 2.56639
# Epoch 153/3000
#  - 45s - loss: 2.5432 - acc: 0.3264 - val_loss: 2.5673 - val_acc: 0.3261
#
# Epoch 00153: val_loss did not improve from 2.56639
# Epoch 154/3000
#  - 45s - loss: 2.5432 - acc: 0.3263 - val_loss: 2.5678 - val_acc: 0.3254
#
# Epoch 00154: val_loss did not improve from 2.56639
# Epoch 155/3000
#  - 45s - loss: 2.5434 - acc: 0.3263 - val_loss: 2.5698 - val_acc: 0.3256
#
# Epoch 00155: val_loss did not improve from 2.56639
# Epoch 156/3000
#  - 45s - loss: 2.5432 - acc: 0.3263 - val_loss: 2.5686 - val_acc: 0.3257
#
# Epoch 00156: val_loss did not improve from 2.56639
# Epoch 157/3000
#  - 45s - loss: 2.5431 - acc: 0.3263 - val_loss: 2.5671 - val_acc: 0.3258
#
# Epoch 00157: val_loss did not improve from 2.56639
# Epoch 158/3000
#  - 45s - loss: 2.5431 - acc: 0.3263 - val_loss: 2.5687 - val_acc: 0.3256
#
# Epoch 00158: val_loss did not improve from 2.56639
# Epoch 159/3000
#  - 45s - loss: 2.5430 - acc: 0.3263 - val_loss: 2.5669 - val_acc: 0.3259
#
# Epoch 00159: val_loss did not improve from 2.56639
# Epoch 160/3000
#  - 45s - loss: 2.5430 - acc: 0.3264 - val_loss: 2.5671 - val_acc: 0.3261
#
# Epoch 00160: val_loss did not improve from 2.56639
# Epoch 161/3000
#  - 45s - loss: 2.5431 - acc: 0.3263 - val_loss: 2.5677 - val_acc: 0.3262
#
# Epoch 00161: val_loss did not improve from 2.56639
# Epoch 162/3000
#  - 45s - loss: 2.5432 - acc: 0.3263 - val_loss: 2.5674 - val_acc: 0.3257
#
# Epoch 00162: val_loss did not improve from 2.56639
# Epoch 163/3000
#  - 45s - loss: 2.5428 - acc: 0.3263 - val_loss: 2.5671 - val_acc: 0.3255
#
# Epoch 00163: val_loss did not improve from 2.56639
# Epoch 164/3000
#  - 45s - loss: 2.5429 - acc: 0.3264 - val_loss: 2.5681 - val_acc: 0.3259
#
# Epoch 00164: val_loss did not improve from 2.56639
# Epoch 165/3000
#  - 45s - loss: 2.5430 - acc: 0.3263 - val_loss: 2.5682 - val_acc: 0.3256
#
# Epoch 00165: val_loss did not improve from 2.56639
# Epoch 166/3000
#  - 45s - loss: 2.5429 - acc: 0.3263 - val_loss: 2.5683 - val_acc: 0.3256
#
# Epoch 00166: val_loss did not improve from 2.56639
# Epoch 167/3000
#  - 45s - loss: 2.5428 - acc: 0.3264 - val_loss: 2.5680 - val_acc: 0.3260
#
# Epoch 00167: val_loss did not improve from 2.56639
# Epoch 168/3000
#  - 45s - loss: 2.5430 - acc: 0.3264 - val_loss: 2.5669 - val_acc: 0.3260
#
# Epoch 00168: val_loss did not improve from 2.56639
# Epoch 169/3000
#  - 45s - loss: 2.5427 - acc: 0.3264 - val_loss: 2.5687 - val_acc: 0.3258
#
# Epoch 00169: val_loss did not improve from 2.56639
# Epoch 170/3000
#  - 45s - loss: 2.5431 - acc: 0.3263 - val_loss: 2.5673 - val_acc: 0.3261
#
# Epoch 00170: val_loss did not improve from 2.56639
# Epoch 171/3000
#  - 45s - loss: 2.5429 - acc: 0.3263 - val_loss: 2.5676 - val_acc: 0.3258
# Epoch 00171: val_loss did not improve from 2.56639
# Epoch 172/3000
#  - 45s - loss: 2.5427 - acc: 0.3263 - val_loss: 2.5699 - val_acc: 0.3258
#
# Epoch 00172: val_loss did not improve from 2.56639
# Epoch 173/3000
#  - 45s - loss: 2.5426 - acc: 0.3264 - val_loss: 2.5686 - val_acc: 0.3257
#
# Epoch 00173: val_loss did not improve from 2.56639
# Epoch 174/3000
#  - 45s - loss: 2.5430 - acc: 0.3263 - val_loss: 2.5682 - val_acc: 0.3254
#
# Epoch 00174: val_loss did not improve from 2.56639
# Epoch 175/3000
#  - 45s - loss: 2.5430 - acc: 0.3263 - val_loss: 2.5676 - val_acc: 0.3261
#
# Epoch 00175: val_loss did not improve from 2.56639
# Epoch 176/3000
#  - 45s - loss: 2.5427 - acc: 0.3264 - val_loss: 2.5685 - val_acc: 0.3258
#
# Epoch 00176: val_loss did not improve from 2.56639
# Epoch 177/3000
#  - 45s - loss: 2.5428 - acc: 0.3263 - val_loss: 2.5683 - val_acc: 0.3257
#
# Epoch 00177: val_loss did not improve from 2.56639
# Epoch 178/3000
#  - 45s - loss: 2.5425 - acc: 0.3263 - val_loss: 2.5687 - val_acc: 0.3252
#
# Epoch 00178: val_loss did not improve from 2.56639
# Epoch 179/3000
#  - 45s - loss: 2.5426 - acc: 0.3263 - val_loss: 2.5677 - val_acc: 0.3255
#
# Epoch 00179: val_loss did not improve from 2.56639
# Epoch 180/3000
#  - 45s - loss: 2.5426 - acc: 0.3263 - val_loss: 2.5670 - val_acc: 0.3258
#
# Epoch 00180: val_loss did not improve from 2.56639
# Epoch 181/3000
#  - 45s - loss: 2.5427 - acc: 0.3263 - val_loss: 2.5660 - val_acc: 0.3260
#
# Epoch 00181: val_loss improved from 2.56639 to 2.56597, saving model to conv1d.model
# Epoch 182/3000
#  - 45s - loss: 2.5428 - acc: 0.3264 - val_loss: 2.5674 - val_acc: 0.3260
#
# Epoch 00182: val_loss did not improve from 2.56597
# Epoch 183/3000
#  - 45s - loss: 2.5426 - acc: 0.3263 - val_loss: 2.5670 - val_acc: 0.3260
#
# Epoch 00183: val_loss did not improve from 2.56597
# Epoch 184/3000
#  - 45s - loss: 2.5424 - acc: 0.3263 - val_loss: 2.5676 - val_acc: 0.3255
#
# Epoch 00184: val_loss did not improve from 2.56597
# Epoch 185/3000
#  - 45s - loss: 2.5425 - acc: 0.3264 - val_loss: 2.5671 - val_acc: 0.3262
#
# Epoch 00185: val_loss did not improve from 2.56597
# Epoch 186/3000
#  - 45s - loss: 2.5425 - acc: 0.3263 - val_loss: 2.5680 - val_acc: 0.3253
#
# Epoch 00186: val_loss did not improve from 2.56597
# Epoch 187/3000
#  - 45s - loss: 2.5422 - acc: 0.3263 - val_loss: 2.5679 - val_acc: 0.3260
#
# Epoch 00187: val_loss did not improve from 2.56597
# Epoch 188/3000
#  - 45s - loss: 2.5423 - acc: 0.3263 - val_loss: 2.5685 - val_acc: 0.3258
#
# Epoch 00188: val_loss did not improve from 2.56597
# Epoch 189/3000
#  - 45s - loss: 2.5424 - acc: 0.3263 - val_loss: 2.5683 - val_acc: 0.3258
#
# Epoch 00189: val_loss did not improve from 2.56597
# Epoch 190/3000
#  - 45s - loss: 2.5423 - acc: 0.3263 - val_loss: 2.5680 - val_acc: 0.3260
#
# Epoch 00190: val_loss did not improve from 2.56597
# Epoch 191/3000
#  - 45s - loss: 2.5423 - acc: 0.3262 - val_loss: 2.5684 - val_acc: 0.3257
#
# Epoch 00191: val_loss did not improve from 2.56597
# Epoch 192/3000
#  - 45s - loss: 2.5422 - acc: 0.3263 - val_loss: 2.5676 - val_acc: 0.3261
#
# Epoch 00192: val_loss did not improve from 2.56597
# Epoch 193/3000
#  - 45s - loss: 2.5424 - acc: 0.3263 - val_loss: 2.5676 - val_acc: 0.3257
#
# Epoch 00193: val_loss did not improve from 2.56597
# Epoch 194/3000
#  - 45s - loss: 2.5422 - acc: 0.3263 - val_loss: 2.5680 - val_acc: 0.3261
#
# Epoch 00194: val_loss did not improve from 2.56597
# Epoch 195/3000
#  - 45s - loss: 2.5421 - acc: 0.3265 - val_loss: 2.5691 - val_acc: 0.3257
#
# Epoch 00195: val_loss did not improve from 2.56597
# Epoch 196/3000
#  - 45s - loss: 2.5421 - acc: 0.3264 - val_loss: 2.5672 - val_acc: 0.3257
#
# Epoch 00196: val_loss did not improve from 2.56597
# Epoch 197/3000
#  - 45s - loss: 2.5421 - acc: 0.3263 - val_loss: 2.5673 - val_acc: 0.3259
#
# Epoch 00197: val_loss did not improve from 2.56597
# Epoch 198/3000
#  - 45s - loss: 2.5422 - acc: 0.3263 - val_loss: 2.5673 - val_acc: 0.3257
#
# Epoch 00198: val_loss did not improve from 2.56597
# Epoch 199/3000
#  - 45s - loss: 2.5421 - acc: 0.3263 - val_loss: 2.5676 - val_acc: 0.3258
#
# Epoch 00199: val_loss did not improve from 2.56597
# Epoch 200/3000
#  - 45s - loss: 2.5422 - acc: 0.3263 - val_loss: 2.5673 - val_acc: 0.3260
#
# Epoch 00200: val_loss did not improve from 2.56597
# Epoch 201/3000
#  - 45s - loss: 2.5423 - acc: 0.3263 - val_loss: 2.5684 - val_acc: 0.3255
#
# Epoch 00201: val_loss did not improve from 2.56597
# Epoch 202/3000
#  - 45s - loss: 2.5420 - acc: 0.3263 - val_loss: 2.5686 - val_acc: 0.3260
#
# Epoch 00202: val_loss did not improve from 2.56597
# Epoch 203/3000
#  - 45s - loss: 2.5422 - acc: 0.3263 - val_loss: 2.5672 - val_acc: 0.3259
#
# Epoch 00203: val_loss did not improve from 2.56597
# Epoch 204/3000
#  - 45s - loss: 2.5422 - acc: 0.3264 - val_loss: 2.5688 - val_acc: 0.3255
#
# Epoch 00204: val_loss did not improve from 2.56597
# Epoch 205/3000
#  - 45s - loss: 2.5421 - acc: 0.3264 - val_loss: 2.5681 - val_acc: 0.3255
#
# Epoch 00205: val_loss did not improve from 2.56597
# Epoch 206/3000
#  - 45s - loss: 2.5420 - acc: 0.3263 - val_loss: 2.5669 - val_acc: 0.3261
#
# Epoch 00206: val_loss did not improve from 2.56597
# Epoch 207/3000
#  - 45s - loss: 2.5422 - acc: 0.3264 - val_loss: 2.5680 - val_acc: 0.3255
#
# Epoch 00207: val_loss did not improve from 2.56597
# Epoch 208/3000
#  - 45s - loss: 2.5421 - acc: 0.3264 - val_loss: 2.5674 - val_acc: 0.3260
#
# Epoch 00208: val_loss did not improve from 2.56597
# Epoch 209/3000
#  - 45s - loss: 2.5417 - acc: 0.3263 - val_loss: 2.5670 - val_acc: 0.3259
#
# Epoch 00209: val_loss did not improve from 2.56597
# Epoch 210/3000
#  - 45s - loss: 2.5421 - acc: 0.3263 - val_loss: 2.5670 - val_acc: 0.3259
#
# Epoch 00210: val_loss did not improve from 2.56597
# Epoch 211/3000
#  - 45s - loss: 2.5419 - acc: 0.3263 - val_loss: 2.5685 - val_acc: 0.3255
#
# Epoch 00211: val_loss did not improve from 2.56597
# Epoch 212/3000
#  - 45s - loss: 2.5421 - acc: 0.3264 - val_loss: 2.5694 - val_acc: 0.3255
#
# Epoch 00212: val_loss did not improve from 2.56597
# Epoch 213/3000
#  - 45s - loss: 2.5419 - acc: 0.3263 - val_loss: 2.5677 - val_acc: 0.3262
#
# Epoch 00213: val_loss did not improve from 2.56597
# Epoch 214/3000
#  - 45s - loss: 2.5419 - acc: 0.3264 - val_loss: 2.5676 - val_acc: 0.3256
#
# Epoch 00214: val_loss did not improve from 2.56597
# Epoch 215/3000
#  - 45s - loss: 2.5414 - acc: 0.3263 - val_loss: 2.5676 - val_acc: 0.3259
#
# Epoch 00215: val_loss did not improve from 2.56597
# Epoch 216/3000
#  - 45s - loss: 2.5418 - acc: 0.3263 - val_loss: 2.5691 - val_acc: 0.3257
#
# Epoch 00216: val_loss did not improve from 2.56597
# Epoch 217/3000
#  - 45s - loss: 2.5416 - acc: 0.3263 - val_loss: 2.5678 - val_acc: 0.3261
#
# Epoch 00217: val_loss did not improve from 2.56597
# Epoch 218/3000
#  - 45s - loss: 2.5420 - acc: 0.3264 - val_loss: 2.5680 - val_acc: 0.3255
#
# Epoch 00218: val_loss did not improve from 2.56597
# Epoch 219/3000
#  - 45s - loss: 2.5417 - acc: 0.3263 - val_loss: 2.5680 - val_acc: 0.3255
#
# Epoch 00219: val_loss did not improve from 2.56597
# Epoch 220/3000
#  - 45s - loss: 2.5419 - acc: 0.3263 - val_loss: 2.5680 - val_acc: 0.3255
#
# Epoch 00220: val_loss did not improve from 2.56597
# Epoch 221/3000
#  - 45s - loss: 2.5417 - acc: 0.3264 - val_loss: 2.5681 - val_acc: 0.3259
#
# Epoch 00221: val_loss did not improve from 2.56597
# Epoch 222/3000
#  - 45s - loss: 2.5422 - acc: 0.3263 - val_loss: 2.5674 - val_acc: 0.3258
#
# Epoch 00222: val_loss did not improve from 2.56597
# Epoch 223/3000
#  - 45s - loss: 2.5417 - acc: 0.3263 - val_loss: 2.5678 - val_acc: 0.3256
#
# Epoch 00223: val_loss did not improve from 2.56597
# Epoch 224/3000
#  - 45s - loss: 2.5416 - acc: 0.3263 - val_loss: 2.5679 - val_acc: 0.3259
#
# Epoch 00224: val_loss did not improve from 2.56597
# Epoch 225/3000
#  - 45s - loss: 2.5419 - acc: 0.3264 - val_loss: 2.5674 - val_acc: 0.3257
#
# Epoch 00225: val_loss did not improve from 2.56597
# Epoch 226/3000
#  - 45s - loss: 2.5417 - acc: 0.3263 - val_loss: 2.5691 - val_acc: 0.3258
#
# Epoch 00226: val_loss did not improve from 2.56597
# Epoch 227/3000
#  - 45s - loss: 2.5418 - acc: 0.3263 - val_loss: 2.5675 - val_acc: 0.3256
#
# Epoch 00227: val_loss did not improve from 2.56597
# Epoch 228/3000
#  - 45s - loss: 2.5414 - acc: 0.3264 - val_loss: 2.5680 - val_acc: 0.3260
#
# Epoch 00228: val_loss did not improve from 2.56597
# Epoch 229/3000
#  - 45s - loss: 2.5416 - acc: 0.3263 - val_loss: 2.5680 - val_acc: 0.3253
#
# Epoch 00229: val_loss did not improve from 2.56597
# Epoch 230/3000
#  - 45s - loss: 2.5415 - acc: 0.3263 - val_loss: 2.5673 - val_acc: 0.3258
#
# Epoch 00230: val_loss did not improve from 2.56597
# Epoch 231/3000
#  - 45s - loss: 2.5417 - acc: 0.3264 - val_loss: 2.5687 - val_acc: 0.3261
#
# Epoch 00231: val_loss did not improve from 2.56597
#
# Epoch 00231: ReduceLROnPlateau reducing learning rate to 0.0005.
# Epoch 232/3000
#  - 45s - loss: 2.5418 - acc: 0.3263 - val_loss: 2.5674 - val_acc: 0.3259
#
# Epoch 00232: val_loss did not improve from 2.56597
# Epoch 233/3000
#  - 45s - loss: 2.5415 - acc: 0.3263 - val_loss: 2.5690 - val_acc: 0.3253
#
# Epoch 00233: val_loss did not improve from 2.56597
# Epoch 234/3000
#  - 45s - loss: 2.5415 - acc: 0.3263 - val_loss: 2.5681 - val_acc: 0.3256
#
# Epoch 00234: val_loss did not improve from 2.56597
# Epoch 235/3000
#  - 45s - loss: 2.5416 - acc: 0.3264 - val_loss: 2.5679 - val_acc: 0.3258
#
# Epoch 00235: val_loss did not improve from 2.56597
# Epoch 236/3000
#  - 45s - loss: 2.5418 - acc: 0.3262 - val_loss: 2.5670 - val_acc: 0.3260
#
# Epoch 00236: val_loss did not improve from 2.56597
# Epoch 237/3000
#  - 45s - loss: 2.5414 - acc: 0.3263 - val_loss: 2.5677 - val_acc: 0.3258
#
# Epoch 00237: val_loss did not improve from 2.56597
# Epoch 238/3000
#  - 45s - loss: 2.5416 - acc: 0.3263 - val_loss: 2.5677 - val_acc: 0.3259
#
# Epoch 00238: val_loss did not improve from 2.56597
# Epoch 239/3000
#  - 45s - loss: 2.5413 - acc: 0.3263 - val_loss: 2.5688 - val_acc: 0.3255
#
# Epoch 00239: val_loss did not improve from 2.56597
# Epoch 240/3000
#  - 45s - loss: 2.5413 - acc: 0.3263 - val_loss: 2.5673 - val_acc: 0.3260
#
# Epoch 00240: val_loss did not improve from 2.56597
# Epoch 241/3000
#  - 45s - loss: 2.5415 - acc: 0.3263 - val_loss: 2.5682 - val_acc: 0.3258
#
# Epoch 00241: val_loss did not improve from 2.56597
# Epoch 242/3000
#  - 45s - loss: 2.5413 - acc: 0.3262 - val_loss: 2.5672 - val_acc: 0.3259
#
# Epoch 00242: val_loss did not improve from 2.56597
# Epoch 243/3000
#  - 45s - loss: 2.5414 - acc: 0.3264 - val_loss: 2.5680 - val_acc: 0.3254
#
# Epoch 00243: val_loss did not improve from 2.56597
# Epoch 244/3000
#  - 45s - loss: 2.5414 - acc: 0.3263 - val_loss: 2.5688 - val_acc: 0.3259
#
# Epoch 00244: val_loss did not improve from 2.56597
# Epoch 245/3000
#  - 45s - loss: 2.5414 - acc: 0.3263 - val_loss: 2.5680 - val_acc: 0.3258
#
# Epoch 00245: val_loss did not improve from 2.56597
# Epoch 246/3000
#  - 45s - loss: 2.5415 - acc: 0.3264 - val_loss: 2.5673 - val_acc: 0.3256
#
# Epoch 00246: val_loss did not improve from 2.56597
# Epoch 247/3000
#  - 45s - loss: 2.5412 - acc: 0.3263 - val_loss: 2.5681 - val_acc: 0.3256
#
# Epoch 00247: val_loss did not improve from 2.56597
# Epoch 248/3000
#  - 45s - loss: 2.5412 - acc: 0.3263 - val_loss: 2.5677 - val_acc: 0.3256
#
# Epoch 00248: val_loss did not improve from 2.56597
# Epoch 249/3000
#  - 45s - loss: 2.5414 - acc: 0.3264 - val_loss: 2.5667 - val_acc: 0.3259
#
# Epoch 00249: val_loss did not improve from 2.56597
# Epoch 250/3000
#  - 45s - loss: 2.5415 - acc: 0.3262 - val_loss: 2.5682 - val_acc: 0.3258
#
# Epoch 00250: val_loss did not improve from 2.56597
# Epoch 251/3000
#  - 45s - loss: 2.5414 - acc: 0.3263 - val_loss: 2.5686 - val_acc: 0.3257
#
# Epoch 00251: val_loss did not improve from 2.56597
# Epoch 252/3000
#  - 45s - loss: 2.5413 - acc: 0.3264 - val_loss: 2.5687 - val_acc: 0.3255
#
# Epoch 00252: val_loss did not improve from 2.56597
# Epoch 253/3000
#  - 45s - loss: 2.5413 - acc: 0.3263 - val_loss: 2.5676 - val_acc: 0.3254
#
# Epoch 00253: val_loss did not improve from 2.56597
# Epoch 254/3000
#  - 45s - loss: 2.5414 - acc: 0.3264 - val_loss: 2.5689 - val_acc: 0.3257
#
# Epoch 00254: val_loss did not improve from 2.56597
# Epoch 255/3000
#  - 45s - loss: 2.5412 - acc: 0.3263 - val_loss: 2.5681 - val_acc: 0.3255
#
# Epoch 00255: val_loss did not improve from 2.56597
# Epoch 256/3000
#  - 45s - loss: 2.5411 - acc: 0.3263 - val_loss: 2.5687 - val_acc: 0.3258
#
# Epoch 00256: val_loss did not improve from 2.56597
# Epoch 257/3000
#  - 45s - loss: 2.5411 - acc: 0.3264 - val_loss: 2.5678 - val_acc: 0.3260
#
# Epoch 00257: val_loss did not improve from 2.56597
# Epoch 258/3000
#  - 45s - loss: 2.5410 - acc: 0.3264 - val_loss: 2.5671 - val_acc: 0.3259
#
# Epoch 00258: val_loss did not improve from 2.56597
# Epoch 259/3000
#  - 45s - loss: 2.5412 - acc: 0.3264 - val_loss: 2.5685 - val_acc: 0.3259
#
# Epoch 00259: val_loss did not improve from 2.56597
# Epoch 260/3000
#  - 45s - loss: 2.5410 - acc: 0.3264 - val_loss: 2.5673 - val_acc: 0.3258
#
# Epoch 00260: val_loss did not improve from 2.56597
# Epoch 261/3000
#  - 45s - loss: 2.5410 - acc: 0.3263 - val_loss: 2.5700 - val_acc: 0.3258
#
# Epoch 00261: val_loss did not improve from 2.56597
# Epoch 262/3000
#  - 45s - loss: 2.5410 - acc: 0.3263 - val_loss: 2.5680 - val_acc: 0.3257
#
# Epoch 00262: val_loss did not improve from 2.56597
# Epoch 263/3000
#  - 45s - loss: 2.5410 - acc: 0.3264 - val_loss: 2.5673 - val_acc: 0.3256
#
# Epoch 00263: val_loss did not improve from 2.56597
# Epoch 264/3000
#  - 45s - loss: 2.5415 - acc: 0.3263 - val_loss: 2.5680 - val_acc: 0.3261
#
# Epoch 00264: val_loss did not improve from 2.56597
# Epoch 265/3000
#  - 45s - loss: 2.5410 - acc: 0.3263 - val_loss: 2.5685 - val_acc: 0.3256
#
# Epoch 00265: val_loss did not improve from 2.56597
# Epoch 266/3000
#  - 45s - loss: 2.5411 - acc: 0.3263 - val_loss: 2.5682 - val_acc: 0.3259
#
# Epoch 00266: val_loss did not improve from 2.56597
# Epoch 267/3000
#  - 45s - loss: 2.5412 - acc: 0.3263 - val_loss: 2.5681 - val_acc: 0.3259
#
# Epoch 00267: val_loss did not improve from 2.56597
# Epoch 268/3000
#  - 45s - loss: 2.5412 - acc: 0.3263 - val_loss: 2.5683 - val_acc: 0.3257
#
# Epoch 00268: val_loss did not improve from 2.56597
# Epoch 269/3000
#  - 45s - loss: 2.5411 - acc: 0.3262 - val_loss: 2.5668 - val_acc: 0.3261
#
# Epoch 00269: val_loss did not improve from 2.56597
# Epoch 270/3000
#  - 45s - loss: 2.5409 - acc: 0.3263 - val_loss: 2.5672 - val_acc: 0.3258
#
# Epoch 00270: val_loss did not improve from 2.56597
# Epoch 271/3000
#  - 45s - loss: 2.5412 - acc: 0.3263 - val_loss: 2.5681 - val_acc: 0.3259
#
# Epoch 00271: val_loss did not improve from 2.56597
# Epoch 272/3000
#  - 45s - loss: 2.5408 - acc: 0.3264 - val_loss: 2.5671 - val_acc: 0.3260
#
# Epoch 00272: val_loss did not improve from 2.56597
# Epoch 273/3000
#  - 45s - loss: 2.5410 - acc: 0.3263 - val_loss: 2.5683 - val_acc: 0.3257
#
# Epoch 00273: val_loss did not improve from 2.56597
# Epoch 274/3000
#  - 45s - loss: 2.5410 - acc: 0.3263 - val_loss: 2.5678 - val_acc: 0.3260
#
# Epoch 00274: val_loss did not improve from 2.56597
# Epoch 275/3000
#  - 45s - loss: 2.5411 - acc: 0.3264 - val_loss: 2.5675 - val_acc: 0.3255
#
# Epoch 00275: val_loss did not improve from 2.56597
# Epoch 276/3000
#  - 46s - loss: 2.5409 - acc: 0.3263 - val_loss: 2.5679 - val_acc: 0.3257
#
# Epoch 00276: val_loss did not improve from 2.56597
# Epoch 277/3000
#  - 45s - loss: 2.5410 - acc: 0.3263 - val_loss: 2.5674 - val_acc: 0.3254
#
# Epoch 00277: val_loss did not improve from 2.56597
# Epoch 278/3000
#  - 45s - loss: 2.5406 - acc: 0.3264 - val_loss: 2.5687 - val_acc: 0.3259
#
# Epoch 00278: val_loss did not improve from 2.56597
# Epoch 279/3000
#  - 45s - loss: 2.5410 - acc: 0.3263 - val_loss: 2.5671 - val_acc: 0.3258
#
# Epoch 00279: val_loss did not improve from 2.56597
# Epoch 280/3000
#  - 45s - loss: 2.5409 - acc: 0.3262 - val_loss: 2.5681 - val_acc: 0.3257
#
# Epoch 00280: val_loss did not improve from 2.56597
# Epoch 281/3000
#  - 45s - loss: 2.5410 - acc: 0.3264 - val_loss: 2.5699 - val_acc: 0.3251
#
# Epoch 00281: val_loss did not improve from 2.56597
#
# Epoch 00281: ReduceLROnPlateau reducing learning rate to 0.0005.
# Epoch 00281: early stopping
# total time took: 212.34mins
